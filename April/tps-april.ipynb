# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tabular-playground-series-apr-2021/sample_submission.csv
# /kaggle/input/tabular-playground-series-apr-2021/train.csv
# /kaggle/input/tabular-playground-series-apr-2021/test.csv

# %% [markdown]
# This kernel is just more explanied version of the kernel https://www.kaggle.com/pranjalverma08/tps-april-21-the-ann-approach-score-80-782 .
#
# For me I liked this kernel and wanted to get the feel of what is going on.

# %%
# !pip uninstall scikit-learn 
# !pip install scikit-learn==0.24.1
# Out:
# WARNING: Ignoring invalid distribution -cikit-learn (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/opt/conda/lib/python3.7/site-packages)
# Requirement already satisfied: scikit-learn==0.24.1 in /opt/conda/lib/python3.7/site-packages (0.24.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.24.1) (1.19.5)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.24.1) (1.6.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.24.1) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.24.1) (1.0.1)
# WARNING: Ignoring invalid distribution -cikit-learn (/opt/conda/lib/python3.7/site-packages)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: Ignoring invalid distribution -cikit-learn (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/opt/conda/lib/python3.7/site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (/opt/conda/lib/python3.7/site-packages)

# %%
import sklearn
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.24.1.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import theano
import tensorflow
import keras
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout

from sklearn.experimental import enable_halving_search_cv  
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.model_selection import HalvingRandomSearchCV

# %% [markdown]
# # Reading Data

# %%
train_df = pd.read_csv("/kaggle/input/tabular-playground-series-apr-2021/train.csv")
test_df = pd.read_csv("/kaggle/input/tabular-playground-series-apr-2021/test.csv")

# %% [markdown]
# Description of Data
#
# 1. <b>survival: Survival 0 = No, 1 = Yes
# 1. <b>  pclass: Ticket class1 = 1st, 2 = 2nd, 3 = 3rd
# 1. <b>  sex: Sex
# 1. <b>  Age: Age in years
# 1. <b> sibsp: # of siblings / spouses aboard the Titanic
# 1. <b>  parch: # of parents / children aboard the Titanic
# 1. <b>  ticket: Ticket number
# 1. <b>  fare: Passenger fare
# 1. <b> cabin: Cabin number
# 1. <b> embarked: Port of Embarkation </b>

# %%
summary = pd.DataFrame(train_df.dtypes, columns = ["Dtypes"])
summary["Null"] = train_df.isnull().sum()
summary["first"] = train_df.iloc[0]
summary["second"] = train_df.iloc[1]
summary["third"] = train_df.iloc[2]
summary["unique"] = train_df.nunique()
print(len(train_df))
print(len(test_df))
# Out:
# 100000
# 100000

# %%
train_df
# Out:
#        PassengerId  Survived  Pclass                Name     Sex    Age  \
# 0                0         1       1    Oconnor, Frankie    male    NaN
# 1                1         0       3         Bryan, Drew    male    NaN
# 2                2         0       3      Owens, Kenneth    male   0.33
# 3                3         0       3       Kramer, James    male  19.00
# 4                4         1       3       Bond, Michael    male  25.00
# ...            ...       ...     ...                 ...     ...    ...
# 99995        99995         1       2         Bell, Adele  female  62.00
# 99996        99996         0       2       Brown, Herman    male  66.00
# 99997        99997         0       3  Childress, Charles    male  37.00
# 99998        99998         0       3    Caughlin, Thomas    male  51.00
# 99999        99999         0       3       Enciso, Tyler    male  55.00
#
#        SibSp  Parch     Ticket   Fare   Cabin Embarked
# 0          2      0     209245  27.14  C12239        S
# 1          0      0      27323  13.35     NaN        S
# 2          1      2  CA 457703  71.29     NaN        S
# 3          0      0   A. 10866  13.04     NaN        S
# 4          0      0     427635   7.76     NaN        S
# ...      ...    ...        ...    ...     ...      ...
# 99995      0      0   PC 15008  14.86  D17243        C
# 99996      0      0      13273  11.15     NaN        S
# 99997      0      0        NaN   9.95     NaN        S
# 99998      0      1     458654  30.92     NaN        S
# 99999      0      0     458074  13.96     NaN        S
#
# [100000 rows x 12 columns]

# %% [markdown]
# We can see that there are total of 100k rows in both train and test data.

# %%
summary
# Out:
#               Dtypes   Null             first       second           third  \
# PassengerId    int64      0                 0            1               2
# Survived       int64      0                 1            0               0
# Pclass         int64      0                 1            3               3
# Name          object      0  Oconnor, Frankie  Bryan, Drew  Owens, Kenneth
# Sex           object      0              male         male            male
# Age          float64   3292               NaN          NaN            0.33
# SibSp          int64      0                 2            0               1
# Parch          int64      0                 0            0               2
# Ticket        object   4623            209245        27323       CA 457703
# Fare         float64    134             27.14        13.35           71.29
# Cabin         object  67866            C12239          NaN             NaN
# Embarked      object    250                 S            S               S
#
#              unique
# PassengerId  100000
# Survived          2
# Pclass            3
# Name          92144
# Sex               2
# Age             173
# SibSp             7
# Parch             8
# Ticket        75331
# Fare          15935
# Cabin         26992
# Embarked          3

# %% [markdown]
# There are few null values in Ticket till Embarked column. There are names which are repetetive.

# %%
train_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # Feature Engineering

# %%
train_df['Survived'].value_counts()
# To get the idea how the data is dustributed. what if it's unbalanced.
# Out:
# 0    57226
# 1    42774
# Name: Survived, dtype: int64

# %% [markdown]
# ### Checking the correlation

# %%
train_df[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# To get the idea of how the chance to survive is related to the sibsp, lower the number of sibsp higher the chance of survival but not really

train_df[["Sex", "Survived"]].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# To get the chance of survival based on the sex, females have comparatively higher chances than men.

train_df[["Parch", "Survived"]].groupby(['Parch'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# To check the correlation between the parents/children to chances of survival.

train_df[["Embarked", "Survived"]].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# To check the correlation between the Embarked and chances of survival.
# Out:
#   Embarked  Survived
# 0        C  0.751296
# 1        Q  0.596976
# 2        S  0.315294

# %% [markdown]
# ### Making copy of original dataset and dropping the unnecessary columns.

# %%
train_copy = train_df.copy()# made a copy of train and test sets
test_copy = test_df.copy()

train = train_df.drop(['PassengerId', 'Ticket'], axis = 1) # Dropping the unncessary column
test = test_df.drop(['PassengerId', 'Ticket',], axis = 1)

combine = [train, test] # combining both training and test set.

# %% [markdown]
# ### Filling Null values and modifying values

# %%
train['Cabin'].fillna('U', inplace=True) # filling the null values with U i,e undefined
train['Cabin'] = train['Cabin'].apply(lambda x: x[0]) # filling all the values with the first alphabet that appeared!

test['Cabin'].fillna('U', inplace=True)
test['Cabin'] = test['Cabin'].apply(lambda x: x[0])

train['Cabin'].unique()
for dataset in combine:
    dataset['Cabin'] = dataset['Cabin'].fillna('U')
    dataset['Cabin'] = dataset['Cabin'].apply(lambda x: x[0])

# %% [markdown]
# ### Checking correlation and creating frequency table

# %%
pd.crosstab(train['Cabin'], train['Survived'])
# To get the frequency between cabin and survived
train[['Cabin', 'Survived']].groupby(['Cabin'], as_index = False).mean().sort_values(by = 'Survived', ascending = True)
# Get the correlarion between both and cabin and Survived columns
cabin_mapping = {"T": 0, "U": 1, "A": 2, "G": 3, "C": 4, "F": 5, "B": 6, "E": 7, "D": 8}

for dataset in combine:
    dataset['Cabin'] = dataset['Cabin'].map(cabin_mapping)
    dataset['Cabin'] = dataset['Cabin'].fillna(0)

# %% [markdown]
# ### Creating frequency table for title and sex column

# %%
for dataset in combine:
    dataset['Title'] = dataset['Name'].map(lambda x: x.split(',')[1].split('.')[0].strip())

pd.crosstab(train['Title'], train['Sex'])
  
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

# %% [markdown]
# # Imputing Missing Values

# %%
train.isnull().sum()
test.isnull().sum()
# Out:
# Pclass         0
# Name           0
# Sex            0
# Age         3487
# SibSp          0
# Parch          0
# Fare         133
# Cabin          0
# Embarked     277
# Title          0
# dtype: int64

# %%
train['Age'].fillna(train['Age'].dropna().median(), inplace=True) # With median
test['Age'].fillna(train['Age'].mean(), inplace = True)# With mean

test['Fare'].fillna(train['Fare'].dropna().median(), inplace = True)# With median
train['Fare'].fillna(train['Fare'].dropna().median(), inplace = True)

train['Embarked'].fillna('C', inplace = True)
test['Embarked'].fillna('C', inplace = True)

train.drop('Title',axis=1,inplace=True) # dropping the title column
test.drop('Title',axis=1,inplace=True)

# %% [markdown]
# ### Sanity check

# %%
train.isnull().sum()
test.isnull().sum()
# Out:
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %% [markdown]
# ### Discretizing into bins

# %%
train['AgeBand'] = pd.cut(train['Age'], 5)
train[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean().sort_values(by='AgeBand', ascending=True)
# Out:
#               AgeBand  Survived
# 0  (-0.00692, 17.464]  0.437358
# 1    (17.464, 34.848]  0.341962
# 2    (34.848, 52.232]  0.447088
# 3    (52.232, 69.616]  0.485275
# 4      (69.616, 87.0]  0.632806

# %% [markdown]
# ### Categorising the Data

# %%
for dataset in combine:    
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 4
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 64, 'Age'] = 0

# %%
dataset.Age.unique()
# Out:
# array([1., 3., 2., 4., 0.])

# %%
for dataset in combine:
    dataset['FamilySize'] = dataset['SibSp'] + dataset['Parch'] + 1
train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#     FamilySize  Survived
# 1            2  0.516254
# 15          18  0.500000
# 2            3  0.482436
# 9           10  0.452229
# 11          12  0.450000
# 5            6  0.440345
# 10          11  0.414062
# 3            4  0.409194
# 0            1  0.404394
# 4            5  0.335294
# 6            7  0.325301
# 12          13  0.285714
# 7            8  0.269231
# 8            9  0.252252
# 13          14  0.200000
# 14          15  0.000000

# %%
for dataset in combine:
    dataset['Embarked'] = dataset['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

# %%
train['FareBand'] = pd.qcut(train['Fare'], 4)
train[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False).mean().sort_values(by='FareBand', ascending=True)
for dataset in combine:
    dataset.loc[ dataset['Fare'] <= 7.91, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 7.91) & (dataset['Fare'] <= 14.454), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 14.454) & (dataset['Fare'] <= 31), 'Fare']   = 2
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3
    dataset['Fare'] = dataset['Fare'].astype(int)
train = train.drop(['FareBand'], axis=1)
combine = [train, test]

# %%
train = train.drop(['AgeBand', 'Name', 'SibSp', 'Parch' ], axis = 1)
test = test.drop(['Name', 'SibSp', 'Parch'], axis = 1)

# %%
x_train = train.drop('Survived', axis = 1)
y_train = train.Survived

x_test = test

# %%
horizontal_stack = pd.concat([x_train, y_train], axis=1)
horizontal_stack.index+=1
train_df=horizontal_stack

# %%
x_test.index+=100000
test_df=x_test

# %%
test_df
# Out:
#         Pclass  Sex  Age  Fare  Cabin  Embarked  FamilySize
# 100000       3    0  1.0     3      1         0           1
# 100001       3    1  3.0     0      1         0           1
# 100002       1    1  1.0     3      6         1           1
# 100003       2    0  1.0     1      1         0           1
# 100004       1    1  1.0     2      6         1           3
# ...        ...  ...  ...   ...    ...       ...         ...
# 199995       3    1  1.0     1      1         2           1
# 199996       1    0  3.0     3      1         0           2
# 199997       3    0  2.0     1      1         0           1
# 199998       1    1  3.0     2      6         1           4
# 199999       1    1  2.0     3      7         1           3
#
# [100000 rows x 7 columns]

# %% [markdown]
# <b>After so much of things that we did, at this point it is okay to get lost of what are we trying to acheive here, so I tried my way to describe what all we have done through up until now.
#
# <b> I hope this is helpful to you as well.
#
# 1. So at first we look at the files we have at our disposal.
# 1. Then we imported all the libraries up until now.
# 1. We read the data
# 1. We summarized the data to get more familiar with data, with how many null values are there and what data types of values are there, we also looked at the number of unique values of each column.
# 1. Then we went through the steps of Feature Engineering where in
# 1. We first had a look at whether our training var is skewed or normalized.
# 2. We checked the correlation between few columns to get more familiar with them.
# 3. We then made the copy of our original dataset.
# 4. We dropped unnecessary columns, i.e passengerId and Ticket.
# 5. We then imputed the null values with U for cabin and also modified its values.
# 6. Later we then checked the correlation of cabin with survived column.
# 7. The reason why we have a combine dataset because it will make things easier if we want to change something which will hold true for both Train and Test set.
# 8. We then mapped the name column with its first name and did the change for both train and test set.
# 9. We looked the frequency table between newly created Title column which holds the first name of the Name col and then look at the correlation between it and Sex column which did tell much information.
# 10. Categorised the Sex column
# 11. Imputed missing values for all the columns which has missing values.
# 12. Dropped the Title column.
# 13. Discretized into bins for column Age and created a new column, AgeBand and checked its corerlation
# 14. Added a new feature name FamilySize and checked its correlation.
# 15. Categorised the Embarked feature.
# 16. Discretized the Fare feature and checked its correlation and dropped the Fareband feature created while discretizing.
# 17. Dropped the Name, Sibsp and Parch feature.
# 18. Get the target feature and remove it from train data.
# 19. Get the horizontal_Stack and then get the test_df
# 20. Split the data

# %% [markdown]
# # Model Building

# %% [markdown]
# ### Getting target variable and splitting the data

# %%
y=train_df['Survived']
X=train_df.drop('Survived', axis =1)

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=101, test_size=0.25)

# %%
def build_classifier(optimizer):
    classifier = Sequential()
    
    classifier.add(Dense(units=10,kernel_initializer='uniform',activation='relu',input_dim=7))
    classifier.add(Dropout(rate = 0.2))
    
    classifier.add(Dense(units=64,kernel_initializer='uniform',activation='relu'))
    classifier.add(Dropout(rate = 0.2))
    
    classifier.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
    
    #Optimizer and Compilation
    classifier.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])
    
    return classifier

# %%
# %%time
classifier = KerasClassifier(build_fn = build_classifier)
param_grid = dict(optimizer = ['Adam'],
                  epochs=[50,100,200],
                  batch_size=[16,32,64])
grid = HalvingRandomSearchCV(classifier, param_grid, scoring='accuracy', cv=10, n_jobs=-1)
grid_result = grid.fit(X_train, y_train)
best_parameters = grid.best_params_
best_accuracy = grid.best_score_
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_search.py:289: UserWarning: The total space of parameters 9 is smaller than n_iter=3750. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# Epoch 1/200
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.5467 - accuracy: 0.7301
# Epoch 2/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5074 - accuracy: 0.7662
# Epoch 3/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5039 - accuracy: 0.7688
# Epoch 4/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5058 - accuracy: 0.7669
# Epoch 5/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5030 - accuracy: 0.7686
# Epoch 6/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5044 - accuracy: 0.7675
# Epoch 7/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5050 - accuracy: 0.7678
# Epoch 8/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5002 - accuracy: 0.7696
# Epoch 9/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5046 - accuracy: 0.7672
# Epoch 10/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5013 - accuracy: 0.7686
# Epoch 11/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5027 - accuracy: 0.7670
# Epoch 12/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5035 - accuracy: 0.7686
# Epoch 13/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5027 - accuracy: 0.7685
# Epoch 14/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5006 - accuracy: 0.7697
# Epoch 15/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5038 - accuracy: 0.7678
# Epoch 16/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5004 - accuracy: 0.7689
# Epoch 17/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5003 - accuracy: 0.7695
# Epoch 18/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4996 - accuracy: 0.7696
# Epoch 19/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5004 - accuracy: 0.7690
# Epoch 20/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4993 - accuracy: 0.7702
# Epoch 21/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5029 - accuracy: 0.7673
# Epoch 22/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5023 - accuracy: 0.7672
# Epoch 23/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4990 - accuracy: 0.7698
# Epoch 24/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5014 - accuracy: 0.7686
# Epoch 25/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5016 - accuracy: 0.7681
# Epoch 26/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5001 - accuracy: 0.7683
# Epoch 27/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4982 - accuracy: 0.7726
# Epoch 28/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4968 - accuracy: 0.7711
# Epoch 29/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4976 - accuracy: 0.7702
# Epoch 30/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4960 - accuracy: 0.7723
# Epoch 31/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5042 - accuracy: 0.7662
# Epoch 32/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4974 - accuracy: 0.7738
# Epoch 33/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4994 - accuracy: 0.7709
# Epoch 34/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5023 - accuracy: 0.7684
# Epoch 35/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5034 - accuracy: 0.7673
# Epoch 36/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4972 - accuracy: 0.7717
# Epoch 37/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4989 - accuracy: 0.7700
# Epoch 38/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5000 - accuracy: 0.7690
# Epoch 39/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5001 - accuracy: 0.7683
# Epoch 40/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5004 - accuracy: 0.7689
# Epoch 41/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4968 - accuracy: 0.7712
# Epoch 42/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4991 - accuracy: 0.7708
# Epoch 43/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5013 - accuracy: 0.7677
# Epoch 44/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4991 - accuracy: 0.7692
# Epoch 45/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4986 - accuracy: 0.7694
# Epoch 46/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4993 - accuracy: 0.7678
# Epoch 47/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5007 - accuracy: 0.7690
# Epoch 48/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5002 - accuracy: 0.7677
# Epoch 49/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5008 - accuracy: 0.7682
# Epoch 50/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5020 - accuracy: 0.7702
# Epoch 51/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4990 - accuracy: 0.7681
# Epoch 52/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4961 - accuracy: 0.7717
# Epoch 53/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5017 - accuracy: 0.7675
# Epoch 54/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5012 - accuracy: 0.7675
# Epoch 55/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4968 - accuracy: 0.7711
# Epoch 56/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5003 - accuracy: 0.7683
# Epoch 57/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4999 - accuracy: 0.7673
# Epoch 58/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5000 - accuracy: 0.7686
# Epoch 59/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4964 - accuracy: 0.7714
# Epoch 60/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4973 - accuracy: 0.7694
# Epoch 61/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4988 - accuracy: 0.7698
# Epoch 62/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5008 - accuracy: 0.7683
# Epoch 63/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4991 - accuracy: 0.7689
# Epoch 64/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4947 - accuracy: 0.7723
# Epoch 65/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4962 - accuracy: 0.7724
# Epoch 66/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5010 - accuracy: 0.7682
# Epoch 67/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4972 - accuracy: 0.7714
# Epoch 68/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4994 - accuracy: 0.7700
# Epoch 69/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4956 - accuracy: 0.7701
# Epoch 70/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4999 - accuracy: 0.7697
# Epoch 71/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4989 - accuracy: 0.7718
# Epoch 72/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4987 - accuracy: 0.7687
# Epoch 73/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4980 - accuracy: 0.7688
# Epoch 74/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5011 - accuracy: 0.7676
# Epoch 75/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4994 - accuracy: 0.7690
# Epoch 76/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5003 - accuracy: 0.7694
# Epoch 77/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4964 - accuracy: 0.7719
# Epoch 78/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4964 - accuracy: 0.7702
# Epoch 79/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4987 - accuracy: 0.7691
# Epoch 80/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4984 - accuracy: 0.7689
# Epoch 81/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4944 - accuracy: 0.7724
# Epoch 82/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4986 - accuracy: 0.7697
# Epoch 83/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5003 - accuracy: 0.7665
# Epoch 84/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5000 - accuracy: 0.7680
# Epoch 85/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4974 - accuracy: 0.7707
# Epoch 86/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4958 - accuracy: 0.7695
# Epoch 87/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4991 - accuracy: 0.7691
# Epoch 88/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4998 - accuracy: 0.7669
# Epoch 89/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4964 - accuracy: 0.7695
# Epoch 90/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4989 - accuracy: 0.7700
# Epoch 91/200
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.4988 - accuracy: 0.7709
# Epoch 92/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4957 - accuracy: 0.7717
# Epoch 93/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4954 - accuracy: 0.7712
# Epoch 94/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5029 - accuracy: 0.7679
# Epoch 95/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5004 - accuracy: 0.7676
# Epoch 96/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4959 - accuracy: 0.7712
# Epoch 97/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5003 - accuracy: 0.7679
# Epoch 98/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4962 - accuracy: 0.7710
# Epoch 99/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4983 - accuracy: 0.7700
# Epoch 100/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4944 - accuracy: 0.7699
# Epoch 101/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4985 - accuracy: 0.7686
# Epoch 102/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4960 - accuracy: 0.7706
# Epoch 103/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4954 - accuracy: 0.7713
# Epoch 104/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4964 - accuracy: 0.7723
# Epoch 105/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4950 - accuracy: 0.7706
# Epoch 106/200
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.4961 - accuracy: 0.7716
# Epoch 107/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4952 - accuracy: 0.7723
# Epoch 108/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4962 - accuracy: 0.7693
# Epoch 109/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4942 - accuracy: 0.7704
# Epoch 110/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4985 - accuracy: 0.7679
# Epoch 111/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4968 - accuracy: 0.7682
# Epoch 112/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4940 - accuracy: 0.7706
# Epoch 113/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4984 - accuracy: 0.7680
# Epoch 114/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4964 - accuracy: 0.7710
# Epoch 115/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4965 - accuracy: 0.7684
# Epoch 116/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4946 - accuracy: 0.7702
# Epoch 117/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4970 - accuracy: 0.7684
# Epoch 118/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4961 - accuracy: 0.7702
# Epoch 119/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4903 - accuracy: 0.7729
# Epoch 120/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4931 - accuracy: 0.7717
# Epoch 121/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4933 - accuracy: 0.7706
# Epoch 122/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4934 - accuracy: 0.7712
# Epoch 123/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4970 - accuracy: 0.7679
# Epoch 124/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4946 - accuracy: 0.7716
# Epoch 125/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5003 - accuracy: 0.7669
# Epoch 126/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4927 - accuracy: 0.7709
# Epoch 127/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4953 - accuracy: 0.7696
# Epoch 128/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4949 - accuracy: 0.7711
# Epoch 129/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4924 - accuracy: 0.7702
# Epoch 130/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4938 - accuracy: 0.7702
# Epoch 131/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4936 - accuracy: 0.7686
# Epoch 132/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4939 - accuracy: 0.7715
# Epoch 133/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4902 - accuracy: 0.7716
# Epoch 134/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4958 - accuracy: 0.7692
# Epoch 135/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4977 - accuracy: 0.7685
# Epoch 136/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4957 - accuracy: 0.7678
# Epoch 137/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4924 - accuracy: 0.7705
# Epoch 138/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4931 - accuracy: 0.7720
# Epoch 139/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4952 - accuracy: 0.7716
# Epoch 140/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4977 - accuracy: 0.7695
# Epoch 141/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4964 - accuracy: 0.7696
# Epoch 142/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4960 - accuracy: 0.7696
# Epoch 143/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4949 - accuracy: 0.7690
# Epoch 144/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4976 - accuracy: 0.7674
# Epoch 145/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4944 - accuracy: 0.7703
# Epoch 146/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4966 - accuracy: 0.7705
# Epoch 147/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4931 - accuracy: 0.7722
# Epoch 148/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4942 - accuracy: 0.7701
# Epoch 149/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4964 - accuracy: 0.7696
# Epoch 150/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4984 - accuracy: 0.7674
# Epoch 151/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4955 - accuracy: 0.7694
# Epoch 152/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4937 - accuracy: 0.7700
# Epoch 153/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4932 - accuracy: 0.7732
# Epoch 154/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4937 - accuracy: 0.7721
# Epoch 155/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4931 - accuracy: 0.7704
# Epoch 156/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4936 - accuracy: 0.7719
# Epoch 157/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4919 - accuracy: 0.7725
# Epoch 158/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4970 - accuracy: 0.7672
# Epoch 159/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4969 - accuracy: 0.7684
# Epoch 160/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4926 - accuracy: 0.7715
# Epoch 161/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4917 - accuracy: 0.7718
# Epoch 162/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4945 - accuracy: 0.7699
# Epoch 163/200
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.4941 - accuracy: 0.7697
# Epoch 164/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4997 - accuracy: 0.7675
# Epoch 165/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4944 - accuracy: 0.7704
# Epoch 166/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4967 - accuracy: 0.7689
# Epoch 167/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4934 - accuracy: 0.7711
# Epoch 168/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4966 - accuracy: 0.7672
# Epoch 169/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4950 - accuracy: 0.7698
# Epoch 170/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4961 - accuracy: 0.7698
# Epoch 171/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4980 - accuracy: 0.7676
# Epoch 172/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4968 - accuracy: 0.7691
# Epoch 173/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4921 - accuracy: 0.7714
# Epoch 174/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4984 - accuracy: 0.7686
# Epoch 175/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4948 - accuracy: 0.7696
# Epoch 176/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4960 - accuracy: 0.7683
# Epoch 177/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4967 - accuracy: 0.7688
# Epoch 178/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4938 - accuracy: 0.7730
# Epoch 179/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4944 - accuracy: 0.7695
# Epoch 180/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4951 - accuracy: 0.7716
# Epoch 181/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4939 - accuracy: 0.7714
# Epoch 182/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4946 - accuracy: 0.7723
# Epoch 183/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4931 - accuracy: 0.7710
# Epoch 184/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4951 - accuracy: 0.7694
# Epoch 185/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4916 - accuracy: 0.7723
# Epoch 186/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4949 - accuracy: 0.7721
# Epoch 187/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4965 - accuracy: 0.7687
# Epoch 188/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4944 - accuracy: 0.7720
# Epoch 189/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4943 - accuracy: 0.7708
# Epoch 190/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4956 - accuracy: 0.7701
# Epoch 191/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4959 - accuracy: 0.7697
# Epoch 192/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4918 - accuracy: 0.7700
# Epoch 193/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4930 - accuracy: 0.7710
# Epoch 194/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4968 - accuracy: 0.7710
# Epoch 195/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4932 - accuracy: 0.7713
# Epoch 196/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4975 - accuracy: 0.7682
# Epoch 197/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4914 - accuracy: 0.7717
# Epoch 198/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4923 - accuracy: 0.7709
# Epoch 199/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4926 - accuracy: 0.7740
# Epoch 200/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4934 - accuracy: 0.7707
# CPU times: user 15min 34s, sys: 2min 48s, total: 18min 23s
# Wall time: 12min 46s

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'optimizer': 'Adam', 'epochs': 200, 'batch_size': 32}
# 0.7944444444444445

# %%
classifier = KerasClassifier(build_fn = build_classifier,
                             optimizer=best_parameters['optimizer'],
                             batch_size=best_parameters['batch_size'],
                             epochs=best_parameters['epochs'])

classifier.fit(X_train,y_train)
preds = classifier.predict(test_df)
# Out:
# Epoch 1/200
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.5471 - accuracy: 0.7310
# Epoch 2/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5071 - accuracy: 0.7684
# Epoch 3/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5083 - accuracy: 0.7652
# Epoch 4/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5059 - accuracy: 0.7642
# Epoch 5/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5027 - accuracy: 0.7691
# Epoch 6/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5036 - accuracy: 0.7679
# Epoch 7/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5069 - accuracy: 0.7664
# Epoch 8/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5070 - accuracy: 0.7654
# Epoch 9/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5037 - accuracy: 0.7673
# Epoch 10/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4996 - accuracy: 0.7710
# Epoch 11/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5053 - accuracy: 0.7669
# Epoch 12/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5030 - accuracy: 0.7690
# Epoch 13/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5047 - accuracy: 0.7663
# Epoch 14/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5033 - accuracy: 0.7685
# Epoch 15/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.5035 - accuracy: 0.7665
# Epoch 16/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.5017 - accuracy: 0.7680
# Epoch 17/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5017 - accuracy: 0.7692
# Epoch 18/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5040 - accuracy: 0.7661
# Epoch 19/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5017 - accuracy: 0.7690
# Epoch 20/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5037 - accuracy: 0.7676
# Epoch 21/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5011 - accuracy: 0.7689
# Epoch 22/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5008 - accuracy: 0.7679
# Epoch 23/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4997 - accuracy: 0.7703
# Epoch 24/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4987 - accuracy: 0.7709
# Epoch 25/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5028 - accuracy: 0.7688
# Epoch 26/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5051 - accuracy: 0.7658
# Epoch 27/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5011 - accuracy: 0.7670
# Epoch 28/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5031 - accuracy: 0.7684
# Epoch 29/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5006 - accuracy: 0.7689
# Epoch 30/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4988 - accuracy: 0.7696
# Epoch 31/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5019 - accuracy: 0.7681
# Epoch 32/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4984 - accuracy: 0.7698
# Epoch 33/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4995 - accuracy: 0.7710
# Epoch 34/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4982 - accuracy: 0.7703
# Epoch 35/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5019 - accuracy: 0.7678
# Epoch 36/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5040 - accuracy: 0.7666
# Epoch 37/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5010 - accuracy: 0.7679
# Epoch 38/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5020 - accuracy: 0.7683
# Epoch 39/200
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.4998 - accuracy: 0.7700
# Epoch 40/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4976 - accuracy: 0.7701
# Epoch 41/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5005 - accuracy: 0.7686
# Epoch 42/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4980 - accuracy: 0.7688
# Epoch 43/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4983 - accuracy: 0.7709
# Epoch 44/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5010 - accuracy: 0.7666
# Epoch 45/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5007 - accuracy: 0.7680
# Epoch 46/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5009 - accuracy: 0.7658
# Epoch 47/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5022 - accuracy: 0.7686
# Epoch 48/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5010 - accuracy: 0.7690
# Epoch 49/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5007 - accuracy: 0.7682
# Epoch 50/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4976 - accuracy: 0.7728
# Epoch 51/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4990 - accuracy: 0.7690
# Epoch 52/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4962 - accuracy: 0.7730
# Epoch 53/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5016 - accuracy: 0.7681
# Epoch 54/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4999 - accuracy: 0.7676
# Epoch 55/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5006 - accuracy: 0.7685
# Epoch 56/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4996 - accuracy: 0.7699
# Epoch 57/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5006 - accuracy: 0.7692
# Epoch 58/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.5001 - accuracy: 0.7691
# Epoch 59/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4992 - accuracy: 0.7705
# Epoch 60/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4942 - accuracy: 0.7746
# Epoch 61/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5007 - accuracy: 0.7680
# Epoch 62/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4975 - accuracy: 0.7712
# Epoch 63/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5002 - accuracy: 0.7693
# Epoch 64/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5024 - accuracy: 0.7659
# Epoch 65/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5019 - accuracy: 0.7693
# Epoch 66/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4973 - accuracy: 0.7713
# Epoch 67/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4993 - accuracy: 0.7691
# Epoch 68/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.5001 - accuracy: 0.7714
# Epoch 69/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4995 - accuracy: 0.7712
# Epoch 70/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4995 - accuracy: 0.7704
# Epoch 71/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5021 - accuracy: 0.7691
# Epoch 72/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5001 - accuracy: 0.7679
# Epoch 73/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4996 - accuracy: 0.7699
# Epoch 74/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5023 - accuracy: 0.7661
# Epoch 75/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5016 - accuracy: 0.7667
# Epoch 76/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4985 - accuracy: 0.7708
# Epoch 77/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.5006 - accuracy: 0.7701
# Epoch 78/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5009 - accuracy: 0.7675
# Epoch 79/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4978 - accuracy: 0.7698
# Epoch 80/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4996 - accuracy: 0.7694
# Epoch 81/200
# 2344/2344 [==============================] - 5s 2ms/step - loss: 0.4999 - accuracy: 0.7682
# Epoch 82/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.5003 - accuracy: 0.7673
# Epoch 83/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.5003 - accuracy: 0.7691
# Epoch 84/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5022 - accuracy: 0.7681
# Epoch 85/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4998 - accuracy: 0.7706
# Epoch 86/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.5027 - accuracy: 0.7669
# Epoch 87/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4983 - accuracy: 0.7709
# Epoch 88/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4994 - accuracy: 0.7691
# Epoch 89/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4985 - accuracy: 0.7694
# Epoch 90/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5016 - accuracy: 0.7690
# Epoch 91/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4987 - accuracy: 0.7696
# Epoch 92/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4978 - accuracy: 0.7719
# Epoch 93/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5002 - accuracy: 0.7674
# Epoch 94/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4963 - accuracy: 0.7728
# Epoch 95/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4980 - accuracy: 0.7693
# Epoch 96/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4982 - accuracy: 0.7688
# Epoch 97/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4975 - accuracy: 0.7711
# Epoch 98/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4993 - accuracy: 0.7690
# Epoch 99/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4980 - accuracy: 0.7683
# Epoch 100/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5003 - accuracy: 0.7687
# Epoch 101/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5001 - accuracy: 0.7675
# Epoch 102/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5002 - accuracy: 0.7698
# Epoch 103/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4990 - accuracy: 0.7661
# Epoch 104/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4985 - accuracy: 0.7680
# Epoch 105/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4971 - accuracy: 0.7717
# Epoch 106/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.5014 - accuracy: 0.7685
# Epoch 107/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5005 - accuracy: 0.7683
# Epoch 108/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5005 - accuracy: 0.7684
# Epoch 109/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4994 - accuracy: 0.7689
# Epoch 110/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5012 - accuracy: 0.7655
# Epoch 111/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4998 - accuracy: 0.7669
# Epoch 112/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4962 - accuracy: 0.7698
# Epoch 113/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4993 - accuracy: 0.7691
# Epoch 114/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4977 - accuracy: 0.7686
# Epoch 115/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4993 - accuracy: 0.7702
# Epoch 116/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4998 - accuracy: 0.7679
# Epoch 117/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4990 - accuracy: 0.7688
# Epoch 118/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4989 - accuracy: 0.7701
# Epoch 119/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4989 - accuracy: 0.7697
# Epoch 120/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4981 - accuracy: 0.7701
# Epoch 121/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5011 - accuracy: 0.7687
# Epoch 122/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4999 - accuracy: 0.7677
# Epoch 123/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5004 - accuracy: 0.7676
# Epoch 124/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.5034 - accuracy: 0.7652
# Epoch 125/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5012 - accuracy: 0.7684
# Epoch 126/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4968 - accuracy: 0.7705
# Epoch 127/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4981 - accuracy: 0.7685
# Epoch 128/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5009 - accuracy: 0.7682
# Epoch 129/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5016 - accuracy: 0.7686
# Epoch 130/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4973 - accuracy: 0.7713
# Epoch 131/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4987 - accuracy: 0.7677
# Epoch 132/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4995 - accuracy: 0.7692
# Epoch 133/200
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.4963 - accuracy: 0.7717
# Epoch 134/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4985 - accuracy: 0.7700
# Epoch 135/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4963 - accuracy: 0.7698
# Epoch 136/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4996 - accuracy: 0.7683
# Epoch 137/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5020 - accuracy: 0.7674
# Epoch 138/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4965 - accuracy: 0.7716
# Epoch 139/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4995 - accuracy: 0.7704
# Epoch 140/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4980 - accuracy: 0.7718
# Epoch 141/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4984 - accuracy: 0.7700
# Epoch 142/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4980 - accuracy: 0.7695
# Epoch 143/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4970 - accuracy: 0.7689
# Epoch 144/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4968 - accuracy: 0.7702
# Epoch 145/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4994 - accuracy: 0.7686
# Epoch 146/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4967 - accuracy: 0.7696
# Epoch 147/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5006 - accuracy: 0.7668
# Epoch 148/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4995 - accuracy: 0.7696
# Epoch 149/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5020 - accuracy: 0.7686
# Epoch 150/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4962 - accuracy: 0.7702
# Epoch 151/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4956 - accuracy: 0.7727
# Epoch 152/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5011 - accuracy: 0.7668
# Epoch 153/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4977 - accuracy: 0.7712
# Epoch 154/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5014 - accuracy: 0.7675
# Epoch 155/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4969 - accuracy: 0.7714
# Epoch 156/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4974 - accuracy: 0.7701
# Epoch 157/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4999 - accuracy: 0.7707
# Epoch 158/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4979 - accuracy: 0.7693
# Epoch 159/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4982 - accuracy: 0.7711
# Epoch 160/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4986 - accuracy: 0.7698
# Epoch 161/200
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.4998 - accuracy: 0.7702
# Epoch 162/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4984 - accuracy: 0.7701
# Epoch 163/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4986 - accuracy: 0.7689
# Epoch 164/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4989 - accuracy: 0.7697
# Epoch 165/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4982 - accuracy: 0.7704
# Epoch 166/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4949 - accuracy: 0.7704
# Epoch 167/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5031 - accuracy: 0.7667
# Epoch 168/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4966 - accuracy: 0.7686
# Epoch 169/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5005 - accuracy: 0.7668
# Epoch 170/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4968 - accuracy: 0.7704
# Epoch 171/200
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.4986 - accuracy: 0.7682
# Epoch 172/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5000 - accuracy: 0.7668
# Epoch 173/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4975 - accuracy: 0.7688
# Epoch 174/200
# 2344/2344 [==============================] - ETA: 0s - loss: 0.4965 - accuracy: 0.77 - 3s 1ms/step - loss: 0.4966 - accuracy: 0.7717
# Epoch 175/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4965 - accuracy: 0.7700
# Epoch 176/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4958 - accuracy: 0.7712
# Epoch 177/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5004 - accuracy: 0.7688
# Epoch 178/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4967 - accuracy: 0.7692
# Epoch 179/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4962 - accuracy: 0.7702
# Epoch 180/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4991 - accuracy: 0.7692
# Epoch 181/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4989 - accuracy: 0.7695
# Epoch 182/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4988 - accuracy: 0.7698
# Epoch 183/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4991 - accuracy: 0.7676
# Epoch 184/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4945 - accuracy: 0.7716
# Epoch 185/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4949 - accuracy: 0.7718
# Epoch 186/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4962 - accuracy: 0.7717
# Epoch 187/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4971 - accuracy: 0.7693
# Epoch 188/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4988 - accuracy: 0.7691
# Epoch 189/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4976 - accuracy: 0.7684
# Epoch 190/200
# 2344/2344 [==============================] - 4s 1ms/step - loss: 0.4967 - accuracy: 0.7702
# Epoch 191/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4953 - accuracy: 0.7715
# Epoch 192/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4964 - accuracy: 0.7712
# Epoch 193/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4982 - accuracy: 0.7700
# Epoch 194/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4959 - accuracy: 0.7693
# Epoch 195/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4981 - accuracy: 0.7696
# Epoch 196/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4960 - accuracy: 0.7711
# Epoch 197/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4967 - accuracy: 0.7713
# Epoch 198/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.5014 - accuracy: 0.7673
# Epoch 199/200
# 2344/2344 [==============================] - 3s 1ms/step - loss: 0.4971 - accuracy: 0.7680
# Epoch 200/200
# 2344/2344 [==============================] - 4s 2ms/step - loss: 0.4948 - accuracy: 0.7711
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
y_final = (preds > 0.5).astype(int).reshape(test_df.shape[0])

output = pd.DataFrame({'PassengerId': test_df.index, 'Survived': y_final})
output.to_csv('pred_ann.csv', index=False)
